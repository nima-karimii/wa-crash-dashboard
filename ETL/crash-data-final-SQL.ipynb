# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine("sqlite:///..//database//WA_Crash_data.db")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
        
# Save reference to the table
Base.classes.keys()
# Out:
# ['CrashData']

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['CrashData', 'fatalities_data']

# %%
columns = inspector.get_columns('CrashData')
for c in columns:
    print(c['name'])
# Out:
# ID
# ACC_ID
# ROAD_NO
# COMMON_ROAD_NAME
# CWAY
# LONGITUDE
# LATITUDE
# CRASH_DATE
# CRASH_TIME
# ACCIDENT_TYPE
# SEVERITY
# EVENT_NATURE
# EVENT_TYPE
# TOTAL_BIKE_INVOLVED
# TOTAL_TRUCK_INVOLVED
# TOTAL_HEAVY_TRUCK_INVOLVED
# TOTAL_MOTOR_CYCLE_INVOLVED
# TOTAL_OTHER_VEHICLES_INVOLVED
# TOTAL_PEDESTRIANS_INVOLVED
# CRASH_TIME_HRS
# CRASH_TIME_MIN
# YEAR
# MONTH
# CRASH_DAYWEEK
# CRASH_TIMEDAY

# %%
Data = Base.classes.CrashData
session = Session(engine)
results = session.query(Data.YEAR)
results[5]
# Out:
# (2019)

# %%
    crash = [
        Data.ACC_ID,
        Data.ROAD_NO,
        Data.CWAY,
        Data.COMMON_ROAD_NAME,
        Data.LONGITUDE,
        Data.LATITUDE,
        Data.ACCIDENT_TYPE,
        Data.EVENT_NATURE,
        Data.EVENT_TYPE,
        Data.TOTAL_BIKE_INVOLVED,
        Data.TOTAL_TRUCK_INVOLVED,
        Data.TOTAL_HEAVY_TRUCK_INVOLVED,
        Data.TOTAL_MOTOR_CYCLE_INVOLVED,
        Data.TOTAL_OTHER_VEHICLES_INVOLVED,
        Data.TOTAL_PEDESTRIANS_INVOLVED,
        Data.CRASH_TIME_HRS,
        Data.YEAR,
        Data.MONTH,
        Data.CRASH_DAYWEEK,
        Data.CRASH_TIMEDAY
    ]
    session = Session(engine)
    print("%%%%%%%%%%%%%%")

    print(session)
    # results = session.query(*crash).filter(Data.YEAR == year).all()
    results = session.query(*crash).all()
# Out:
# %%%%%%%%%%%%%%
# <sqlalchemy.orm.session.Session object at 0x7fba9199c050>

# %%
    Data_json=[]
    smpl_data = {}
    for result in results:
        smpl_data = {}
        smpl_data["ACC_ID"] = result[0]
        smpl_data["ROAD_NO"] = result[1]
        smpl_data["CWAY"] = result[2]
        smpl_data["COMMON_ROAD_NAME"] = result[3]
        smpl_data["LONGITUDE"] = result[4]
        smpl_data["LATITUDE"] = result[5]
        smpl_data["ACCIDENT_TYPE"] = result[6]
        smpl_data["EVENT_NATURE"] = result[7]
        smpl_data["EVENT_TYPE"] = result[8]
        smpl_data["TOTAL_BIKE_INVOLVED"] = result[9]
        smpl_data["TOTAL_TRUCK_INVOLVED"] = result[10]
        smpl_data["TOTAL_HEAVY_TRUCK_INVOLVED"] = result[11]
        smpl_data["TOTAL_MOTOR_CYCLE_INVOLVED"] = result[12]
        smpl_data["TOTAL_OTHER_VEHICLES_INVOLVED"] = result[13]
        smpl_data["TOTAL_PEDESTRIANS_INVOLVED"] = result[14]
        smpl_data["CRASH_TIME_HRS"] = result[15]
        smpl_data["YEAR"] = result[16]
        smpl_data["MONTH"] = result[17]
        smpl_data["CRASH_DAYWEEK"] = result[18]
        smpl_data["CRASH_TIMEDAY"] = result[19]
        Data_json.append(smpl_data)
Data_json
# Out:
# TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9992810',
#   'ROAD_NO': '1270004',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Rokeby Rd',
#   'LONGITUDE': '115.823947',
#   'LATITUDE': '-31.952429',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9992870',
#   'ROAD_NO': '1300277',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Beaufort St',
#   'LONGITUDE': '115.86703',
#   'LATITUDE': '-31.942596',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '9992901',
#   'ROAD_NO': 'H035',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Charles St',
#   'LONGITUDE': '115.852559',
#   'LATITUDE': '-31.934131',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9993456',
#   'ROAD_NO': 'H849',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Reid Hwy',
#   'LONGITUDE': '115.855099',
#   'LATITUDE': '-31.864513',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9994901',
#   'ROAD_NO': '1091114',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Morrison Rd',
#   'LONGITUDE': '116.015219',
#   'LATITUDE': '-31.886132',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 9,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9994907',
#   'ROAD_NO': '1180061',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Samson St',
#   'LONGITUDE': '115.770413',
#   'LATITUDE': '-32.061336',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9994914',
#   'ROAD_NO': '1190594',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Camm Av',
#   'LONGITUDE': '115.859479',
#   'LATITUDE': '-32.049215',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9993015',
#   'ROAD_NO': 'H026',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Guildford Rd',
#   'LONGITUDE': '115.884295',
#   'LATITUDE': '-31.934722',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993476',
#   'ROAD_NO': 'H028',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Morley Dr',
#   'LONGITUDE': '115.917565',
#   'LATITUDE': '-31.889267',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993521',
#   'ROAD_NO': 'H021',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Reid Hwy',
#   'LONGITUDE': '115.812809',
#   'LATITUDE': '-31.857112',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993527',
#   'ROAD_NO': '1270006',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Railway Rd',
#   'LONGITUDE': '115.80802',
#   'LATITUDE': '-31.95627',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993570',
#   'ROAD_NO': '1311665',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Joondalup Dr',
#   'LONGITUDE': '115.766584',
#   'LATITUDE': '-31.751123',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993598',
#   'ROAD_NO': '1100002',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Marmion Av',
#   'LONGITUDE': '115.688437',
#   'LATITUDE': '-31.618498',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 1,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9993107',
#   'ROAD_NO': 'H001',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Shepperton Rd',
#   'LONGITUDE': '115.892063',
#   'LATITUDE': '-31.969405',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 3,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993138',
#   'ROAD_NO': 'H005',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Great Eastern Hwy',
#   'LONGITUDE': '116.081268',
#   'LATITUDE': '-31.901009',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993150',
#   'ROAD_NO': '1240111',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Hay St',
#   'LONGITUDE': '115.873164',
#   'LATITUDE': '-31.958846',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9993644',
#   'ROAD_NO': 'H001',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Albany Hwy',
#   'LONGITUDE': '116.251091',
#   'LATITUDE': '-32.380291',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Animal',
#   'EVENT_TYPE': 'Involving Animal',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9998077',
#   'ROAD_NO': 'H015',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.849298',
#   'LATITUDE': '-32.227504',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 4,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '9998139',
#   'ROAD_NO': 'H028',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Morley Dr',
#   'LONGITUDE': '115.917565',
#   'LATITUDE': '-31.889267',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10000009',
#   'ROAD_NO': '1050708',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Halstead Turn',
#   'LONGITUDE': '115.822849',
#   'LATITUDE': '-32.262915',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10000014',
#   'ROAD_NO': '1092148',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'The Promenade',
#   'LONGITUDE': '115.970496',
#   'LATITUDE': '-31.781105',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10000069',
#   'ROAD_NO': '1090311',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Haddrill Rd',
#   'LONGITUDE': '116.027741',
#   'LATITUDE': '-31.79723',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10001438',
#   'ROAD_NO': 'H012',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Leach Hwy',
#   'LONGITUDE': '115.815713',
#   'LATITUDE': '-32.046237',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10001539',
#   'ROAD_NO': '1080200',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Thomas Rd',
#   'LONGITUDE': '115.972769',
#   'LATITUDE': '-32.207031',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9965990',
#   'ROAD_NO': 'H035',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Wanneroo Rd',
#   'LONGITUDE': '115.814601',
#   'LATITUDE': '-31.79572',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9965994',
#   'ROAD_NO': 'H052',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Brookton Hwy',
#   'LONGITUDE': '119.601048',
#   'LATITUDE': '-32.974403',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Non Collision',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9969411',
#   'ROAD_NO': '1092306',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Main St',
#   'LONGITUDE': '115.966161',
#   'LATITUDE': '-31.782528',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9998215',
#   'ROAD_NO': '1180440',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Rous Head Rd',
#   'LONGITUDE': '115.735945',
#   'LATITUDE': '-32.046972',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9998228',
#   'ROAD_NO': '1140022',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Lawson St',
#   'LONGITUDE': '115.900547',
#   'LATITUDE': '-32.008227',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 1,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10000107',
#   'ROAD_NO': '4212001',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Wellington St',
#   'LONGITUDE': '116.655316',
#   'LATITUDE': '-31.665554',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10000154',
#   'ROAD_NO': '1080200',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Thomas Rd',
#   'LONGITUDE': '115.978015',
#   'LATITUDE': '-32.206992',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10001561',
#   'ROAD_NO': '2040079',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Bourke St',
#   'LONGITUDE': '115.642503',
#   'LATITUDE': '-33.332906',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 1,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 10,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10001571',
#   'ROAD_NO': 'H017',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Tonkin Hwy',
#   'LONGITUDE': '115.963025',
#   'LATITUDE': '-32.131155',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9998313',
#   'ROAD_NO': 'H002',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Stock Rd',
#   'LONGITUDE': '115.798408',
#   'LATITUDE': '-32.100967',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9998352',
#   'ROAD_NO': 'H027',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Orrong Rd',
#   'LONGITUDE': '115.930926',
#   'LATITUDE': '-31.982327',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 4,
#   'CRASH_DAYWEEK': 'Tuesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  ...]
