# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine("sqlite:///db/WA_Crash_data.db")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
        
# Save reference to the table

Base.classes.keys()
# Out:
# ['CrashData']

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['CrashData', 'fatalities_data']

# %%
columns = inspector.get_columns('CrashData')
for c in columns:
    print(c['name'])
# Out:
# ID
# ACC_ID
# ROAD_NO
# COMMON_ROAD_NAME
# CWAY
# LONGITUDE
# LATITUDE
# CRASH_DATE
# CRASH_TIME
# ACCIDENT_TYPE
# SEVERITY
# EVENT_NATURE
# EVENT_TYPE
# TOTAL_BIKE_INVOLVED
# TOTAL_TRUCK_INVOLVED
# TOTAL_HEAVY_TRUCK_INVOLVED
# TOTAL_MOTOR_CYCLE_INVOLVED
# TOTAL_OTHER_VEHICLES_INVOLVED
# TOTAL_PEDESTRIANS_INVOLVED
# CRASH_TIME_HRS
# CRASH_TIME_MIN
# YEAR
# MONTH
# CRASH_DAYWEEK
# CRASH_TIMEDAY

# %%
Data = Base.classes.CrashData
session = Session(engine)
results = session.query(Data.YEAR)
results[5]
# Out:
# (2019)

# %%
    crash = [
        Data.ACC_ID,
        Data.ROAD_NO,
        Data.CWAY,
        Data.COMMON_ROAD_NAME,
        Data.LONGITUDE,
        Data.LATITUDE,
        Data.ACCIDENT_TYPE,
        Data.EVENT_NATURE,
        Data.EVENT_TYPE,
        Data.TOTAL_BIKE_INVOLVED,
        Data.TOTAL_TRUCK_INVOLVED,
        Data.TOTAL_HEAVY_TRUCK_INVOLVED,
        Data.TOTAL_MOTOR_CYCLE_INVOLVED,
        Data.TOTAL_OTHER_VEHICLES_INVOLVED,
        Data.TOTAL_PEDESTRIANS_INVOLVED,
        Data.CRASH_TIME_HRS,
        Data.YEAR,
        Data.MONTH,
        Data.CRASH_DAYWEEK,
        Data.CRASH_TIMEDAY
    ]
    session = Session(engine)
    print("%%%%%%%%%%%%%%")

    print(session)
    # results = session.query(*crash).filter(Data.YEAR == year).all()
    results = session.query(*crash).all()
# Out:
# %%%%%%%%%%%%%%
# <sqlalchemy.orm.session.Session object at 0x000001E3E8549848>

# %%
    Data_json=[]
    smpl_data = {}
    i=0
    for result in results:
        i=i+1
        if (i==100): break
        smpl_data = {}
        smpl_data["ACC_ID"] = result[0]
        smpl_data["ROAD_NO"] = result[1]
        smpl_data["CWAY"] = result[2]
        smpl_data["COMMON_ROAD_NAME"] = result[3]
        smpl_data["LONGITUDE"] = result[4]
        smpl_data["LATITUDE"] = result[5]
        smpl_data["ACCIDENT_TYPE"] = result[6]
        smpl_data["EVENT_NATURE"] = result[7]
        smpl_data["EVENT_TYPE"] = result[8]
        smpl_data["TOTAL_BIKE_INVOLVED"] = result[9]
        smpl_data["TOTAL_TRUCK_INVOLVED"] = result[10]
        smpl_data["TOTAL_HEAVY_TRUCK_INVOLVED"] = result[11]
        smpl_data["TOTAL_MOTOR_CYCLE_INVOLVED"] = result[12]
        smpl_data["TOTAL_OTHER_VEHICLES_INVOLVED"] = result[13]
        smpl_data["TOTAL_PEDESTRIANS_INVOLVED"] = result[14]
        smpl_data["CRASH_TIME_HRS"] = result[15]
        smpl_data["YEAR"] = result[16]
        smpl_data["MONTH"] = result[17]
        smpl_data["CRASH_DAYWEEK"] = result[18]
        smpl_data["CRASH_TIMEDAY"] = result[19]
        Data_json.append(smpl_data)
Data_json
# Out:
# [{'ACC_ID': '10034076',
#   'ROAD_NO': '1250106',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Huntriss Rd',
#   'LONGITUDE': '115.787126',
#   'LATITUDE': '-31.888018',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 1,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10034083',
#   'ROAD_NO': '1311665',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Joondalup Dr',
#   'LONGITUDE': '115.78105',
#   'LATITUDE': '-31.770677',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 3,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10036078',
#   'ROAD_NO': '1110006',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Lord St',
#   'LONGITUDE': '115.954109',
#   'LATITUDE': '-31.900235',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10036129',
#   'ROAD_NO': '1300280',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Fitzgerald St',
#   'LONGITUDE': '115.859176',
#   'LATITUDE': '-31.932468',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10014546',
#   'ROAD_NO': '1102151',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Connolly Dr',
#   'LONGITUDE': '115.711603',
#   'LATITUDE': '-31.65169',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10014550',
#   'ROAD_NO': '1092189',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Westgrove Dr',
#   'LONGITUDE': '115.976054',
#   'LATITUDE': '-31.775076',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 21,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10034143',
#   'ROAD_NO': '1250061',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Harborne St',
#   'LONGITUDE': '115.820105',
#   'LATITUDE': '-31.917105',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10034182',
#   'ROAD_NO': 'H005',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Great Eastern Hwy',
#   'LONGITUDE': '115.939667',
#   'LATITUDE': '-31.933303',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 2,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10034196',
#   'ROAD_NO': 'H057',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Forrest Hwy',
#   'LONGITUDE': '115.667964',
#   'LATITUDE': '-33.335838',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10036276',
#   'ROAD_NO': '1260001',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Manning Rd',
#   'LONGITUDE': '115.880854',
#   'LATITUDE': '-32.011969',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10036296',
#   'ROAD_NO': '7060002',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Sandstone - Wiluna Rd',
#   'LONGITUDE': '119.785107',
#   'LATITUDE': '-26.864943',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Animal',
#   'EVENT_TYPE': 'Involving Animal',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10036358',
#   'ROAD_NO': '2120476',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Seawind Dr',
#   'LONGITUDE': '115.740945',
#   'LATITUDE': '-32.501959',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Head On',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10036404',
#   'ROAD_NO': '6052037',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Lane St',
#   'LONGITUDE': '121.473174',
#   'LATITUDE': '-30.754366',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 0,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10039265',
#   'ROAD_NO': 'H009',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'South Western Hwy',
#   'LONGITUDE': '116.004074',
#   'LATITUDE': '-32.320139',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 22,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10041267',
#   'ROAD_NO': '1140022',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Lawson St',
#   'LONGITUDE': '115.900554',
#   'LATITUDE': '-32.012347',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10019110',
#   'ROAD_NO': 'M074',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Mandurah Rd',
#   'LONGITUDE': '115.746159',
#   'LATITUDE': '-32.531387',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10039456',
#   'ROAD_NO': 'H532',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Great Eastern Hwy off to Shepperton Rd & Causeway',
#   'LONGITUDE': '115.890531',
#   'LATITUDE': '-31.966519',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041470',
#   'ROAD_NO': '2180029',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Terry Rd',
#   'LONGITUDE': '116.384608',
#   'LATITUDE': '-33.845923',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Non Collision',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10039469',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.847309',
#   'LATITUDE': '-31.96239',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10041557',
#   'ROAD_NO': '1120017',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Crimea St',
#   'LONGITUDE': '115.904851',
#   'LATITUDE': '-31.890576',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10041569',
#   'ROAD_NO': '1030010',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'North Lake Rd',
#   'LONGITUDE': '115.824172',
#   'LATITUDE': '-32.102513',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041589',
#   'ROAD_NO': 'H012',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Leach Hwy',
#   'LONGITUDE': '115.788939',
#   'LATITUDE': '-32.050204',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041595',
#   'ROAD_NO': 'H028',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Karrinyup Rd',
#   'LONGITUDE': '115.805961',
#   'LATITUDE': '-31.883586',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041609',
#   'ROAD_NO': 'M052',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Boyanup Picton Rd',
#   'LONGITUDE': '115.725525',
#   'LATITUDE': '-33.368307',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10041652',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.84766',
#   'LATITUDE': '-31.97174',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10041693',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.84678',
#   'LATITUDE': '-31.965308',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041769',
#   'ROAD_NO': '1100510',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Civic Dr',
#   'LONGITUDE': '115.80762',
#   'LATITUDE': '-31.751576',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10044409',
#   'ROAD_NO': 'H028',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Morley Dr',
#   'LONGITUDE': '115.88589',
#   'LATITUDE': '-31.888536',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10044415',
#   'ROAD_NO': 'H005',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Great Eastern Hwy',
#   'LONGITUDE': '116.047809',
#   'LATITUDE': '-31.902444',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 3,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10045208',
#   'ROAD_NO': '1190003',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'North Lake Rd',
#   'LONGITUDE': '115.815679',
#   'LATITUDE': '-32.038367',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10090475',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.856661',
#   'LATITUDE': '-32.165808',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10039773',
#   'ROAD_NO': '1220012',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Waratah Av',
#   'LONGITUDE': '115.807291',
#   'LATITUDE': '-31.994809',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10039791',
#   'ROAD_NO': 'H001',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Albany Hwy',
#   'LONGITUDE': '116.012199',
#   'LATITUDE': '-32.088516',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10039857',
#   'ROAD_NO': '1050186',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Mandogalup Rd',
#   'LONGITUDE': '115.830773',
#   'LATITUDE': '-32.189955',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 1,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041828',
#   'ROAD_NO': 'H002',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Stock Rd',
#   'LONGITUDE': '115.798408',
#   'LATITUDE': '-32.100967',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 6,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10041866',
#   'ROAD_NO': 'H001',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Albany Hwy',
#   'LONGITUDE': '117.857337',
#   'LATITUDE': '-34.993624',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Involving Pedestrian',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10041898',
#   'ROAD_NO': '1191645',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Barry Marshall Pde',
#   'LONGITUDE': '115.845168',
#   'LATITUDE': '-32.069731',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10041920',
#   'ROAD_NO': '1260007',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Kent St',
#   'LONGITUDE': '115.888457',
#   'LATITUDE': '-32.006773',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 10,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10039891',
#   'ROAD_NO': '1250135',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Arkana Rd',
#   'LONGITUDE': '115.840778',
#   'LATITUDE': '-31.866417',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 9,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10039897',
#   'ROAD_NO': 'H035',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Wanneroo Rd',
#   'LONGITUDE': '115.81225',
#   'LATITUDE': '-31.791018',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Friday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10046897',
#   'ROAD_NO': 'M045',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Indian Ocean Dr',
#   'LONGITUDE': '115.417996',
#   'LATITUDE': '-31.106033',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Animal',
#   'EVENT_TYPE': 'Involving Animal',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10046932',
#   'ROAD_NO': '1150015',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Chancellor St',
#   'LONGITUDE': '115.791352',
#   'LATITUDE': '-31.975665',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 1,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10044773',
#   'ROAD_NO': '1240096',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kings Park Rd',
#   'LONGITUDE': '115.844374',
#   'LATITUDE': '-31.95405',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10044829',
#   'ROAD_NO': 'H894',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Abernethy Rd on to Leach Hwy (Eastbound)',
#   'LONGITUDE': '115.949004',
#   'LATITUDE': '-31.973455',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10046994',
#   'ROAD_NO': '1141017',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Nicholson Rd',
#   'LONGITUDE': '115.933455',
#   'LATITUDE': '-32.042159',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 3,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10047002',
#   'ROAD_NO': 'H018',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Roe Hwy',
#   'LONGITUDE': '115.879153',
#   'LATITUDE': '-32.07984',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 9,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10047014',
#   'ROAD_NO': '1300334',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Brady St',
#   'LONGITUDE': '115.827669',
#   'LATITUDE': '-31.920625',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10044866',
#   'ROAD_NO': '1250066',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Wiluna St',
#   'LONGITUDE': '115.848663',
#   'LATITUDE': '-31.910897',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 19,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10044895',
#   'ROAD_NO': '1290086',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Cargill St',
#   'LONGITUDE': '115.892525',
#   'LATITUDE': '-31.971751',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10044901',
#   'ROAD_NO': 'H009',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'South Western Hwy',
#   'LONGITUDE': '115.895379',
#   'LATITUDE': '-32.613291',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 6,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10047086',
#   'ROAD_NO': 'H020',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Graham Farmer Fwy',
#   'LONGITUDE': '115.886658',
#   'LATITUDE': '-31.947372',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10047154',
#   'ROAD_NO': '1120013',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Whatley Cr',
#   'LONGITUDE': '115.902027',
#   'LATITUDE': '-31.921916',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10047174',
#   'ROAD_NO': '1072225',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Delta Rd',
#   'LONGITUDE': '115.819864',
#   'LATITUDE': '-32.344784',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10044992',
#   'ROAD_NO': '1250060',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Homer St',
#   'LONGITUDE': '115.873771',
#   'LATITUDE': '-31.908577',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045019',
#   'ROAD_NO': '1250069',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Scarborough Beach Rd',
#   'LONGITUDE': '115.762729',
#   'LATITUDE': '-31.894273',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10045055',
#   'ROAD_NO': 'H633',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Orrong Rd & Welshpool Rd East on to Roe Hwy (Northbound)',
#   'LONGITUDE': '115.975062',
#   'LATITUDE': '-32.00115',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10045067',
#   'ROAD_NO': '1030011',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Russell Rd',
#   'LONGITUDE': '115.811323',
#   'LATITUDE': '-32.157652',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10047234',
#   'ROAD_NO': '1300287',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Loftus St',
#   'LONGITUDE': '115.84416',
#   'LATITUDE': '-31.941232',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 22,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '10047240',
#   'ROAD_NO': '1270009',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Nicholson Rd',
#   'LONGITUDE': '115.821445',
#   'LATITUDE': '-31.956405',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10047253',
#   'ROAD_NO': 'H560',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Mitchell Fwy (Northbound) off to Hutton St',
#   'LONGITUDE': '115.820074',
#   'LATITUDE': '-31.902103',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '10047260',
#   'ROAD_NO': 'H023',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Armadale Rd',
#   'LONGITUDE': '115.898256',
#   'LATITUDE': '-32.136747',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 1,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 8,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10045175',
#   'ROAD_NO': '1240039',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'The Esplanade',
#   'LONGITUDE': '115.858628',
#   'LATITUDE': '-31.956883',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045234',
#   'ROAD_NO': 'H033',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Toodyay Rd',
#   'LONGITUDE': '116.049099',
#   'LATITUDE': '-31.854676',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Involving Animal',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045238',
#   'ROAD_NO': 'H016',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Mitchell Fwy',
#   'LONGITUDE': '115.836501',
#   'LATITUDE': '-31.932611',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045297',
#   'ROAD_NO': 'H017',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Tonkin Hwy',
#   'LONGITUDE': '115.954604',
#   'LATITUDE': '-31.949134',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10045305',
#   'ROAD_NO': '1240112',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Murray St',
#   'LONGITUDE': '115.845418',
#   'LATITUDE': '-31.948526',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Involving Overtaking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045340',
#   'ROAD_NO': '1270012',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Bagot Rd',
#   'LONGITUDE': '115.824963',
#   'LATITUDE': '-31.950439',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10045396',
#   'ROAD_NO': 'H002',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Ennis Av',
#   'LONGITUDE': '115.762926',
#   'LATITUDE': '-32.294527',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10045402',
#   'ROAD_NO': 'H017',
#   'CWAY': 'R',
#   'COMMON_ROAD_NAME': 'Tonkin Hwy',
#   'LONGITUDE': '115.950455',
#   'LATITUDE': '-31.944316',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Wednesday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10043925',
#   'ROAD_NO': 'H017',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Tonkin Hwy',
#   'LONGITUDE': '116.015365',
#   'LATITUDE': '-32.053199',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Monday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10043944',
#   'ROAD_NO': '1120013',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Whatley Cr',
#   'LONGITUDE': '115.902027',
#   'LATITUDE': '-31.921916',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 6,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Monday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '10043958',
#   'ROAD_NO': '1180440',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Rous Head Rd',
#   'LONGITUDE': '115.731652',
#   'LATITUDE': '-32.053272',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 12,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Monday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '10043980',
#   'ROAD_NO': '1250099',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'North Beach Rd',
#   'LONGITUDE': '115.774826',
#   'LATITUDE': '-31.859184',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 10,
#   'YEAR': 2019,
#   'MONTH': 6,
#   'CRASH_DAYWEEK': 'Monday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9956331',
#   'ROAD_NO': '3021001',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'York St',
#   'LONGITUDE': '117.883679',
#   'LATITUDE': '-35.024606',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2019,
#   'MONTH': 2,
#   'CRASH_DAYWEEK': 'Thursday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9875840',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.814482',
#   'LATITUDE': '-32.54442',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Pedestrian',
#   'EVENT_TYPE': 'Involving Pedestrian',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 1,
#   'CRASH_TIME_HRS': 0,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '9902372',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.849249',
#   'LATITUDE': '-32.088183',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 18,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '9902388',
#   'ROAD_NO': '1250102',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Liege St',
#   'LONGITUDE': '115.798348',
#   'LATITUDE': '-31.903661',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9905219',
#   'ROAD_NO': '1310239',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Burns Beach Rd',
#   'LONGITUDE': '115.770635',
#   'LATITUDE': '-31.718354',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Sideswipe Same Dirn',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 14,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9910065',
#   'ROAD_NO': 'H014',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Stirling Hwy',
#   'LONGITUDE': '115.752317',
#   'LATITUDE': '-32.02955',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 10,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9876759',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.856101',
#   'LATITUDE': '-32.009105',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876763',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.856101',
#   'LATITUDE': '-32.009105',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876767',
#   'ROAD_NO': 'M042',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Goodwood Rd',
#   'LONGITUDE': '115.801808',
#   'LATITUDE': '-33.606596',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 1,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 0,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 16,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876891',
#   'ROAD_NO': 'H015',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy',
#   'LONGITUDE': '115.856101',
#   'LATITUDE': '-32.009105',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876895',
#   'ROAD_NO': '1250074',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Flinders St',
#   'LONGITUDE': '115.849395',
#   'LATITUDE': '-31.896667',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Turn Thru',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876899',
#   'ROAD_NO': '1312565',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Savaris Ct',
#   'LONGITUDE': '115.761802',
#   'LATITUDE': '-31.776201',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9876903',
#   'ROAD_NO': '1140552',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Silky Oak L',
#   'LONGITUDE': '115.88701',
#   'LATITUDE': '-32.052904',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 19,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Evening'},
#  {'ACC_ID': '9910522',
#   'ROAD_NO': 'H001',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Albany Hwy',
#   'LONGITUDE': '115.945186',
#   'LATITUDE': '-32.026872',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9910611',
#   'ROAD_NO': 'H551',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Kwinana Fwy (Northbound) off to Canning Hwy',
#   'LONGITUDE': '115.856525',
#   'LATITUDE': '-32.012194',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 0,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '9910618',
#   'ROAD_NO': '1130002',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Abernethy Rd',
#   'LONGITUDE': '115.943098',
#   'LATITUDE': '-31.968221',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 9,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9910791',
#   'ROAD_NO': 'H005',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Great Eastern Hwy',
#   'LONGITUDE': '115.93329',
#   'LATITUDE': '-31.937188',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 5,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '9910849',
#   'ROAD_NO': '1072221',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Pavonia Pde',
#   'LONGITUDE': '115.829421',
#   'LATITUDE': '-32.343856',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 1,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Night'},
#  {'ACC_ID': '9911333',
#   'ROAD_NO': '1300280',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Fitzgerald St',
#   'LONGITUDE': '115.857326',
#   'LATITUDE': '-31.938144',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Rear End',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 17,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9911084',
#   'ROAD_NO': '1040090',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Garden St',
#   'LONGITUDE': '115.948568',
#   'LATITUDE': '-32.079612',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 15,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9909286',
#   'ROAD_NO': 'H009',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'South Coast Hwy',
#   'LONGITUDE': '117.264204',
#   'LATITUDE': '-34.984371',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9876675',
#   'ROAD_NO': '1311335',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Twickenham Dr',
#   'LONGITUDE': '115.787547',
#   'LATITUDE': '-31.799187',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Involving Parking',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 9,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9876679',
#   'ROAD_NO': 'H028',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Karrinyup Rd',
#   'LONGITUDE': '115.765462',
#   'LATITUDE': '-31.873915',
#   'ACCIDENT_TYPE': 'Intersection',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 11,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9911985',
#   'ROAD_NO': '1251362',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Loughton Wy',
#   'LONGITUDE': '115.837436',
#   'LATITUDE': '-31.850448',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Right Angle',
#   'EVENT_TYPE': 'Entering / Leaving Driveway',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 13,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Afternoon'},
#  {'ACC_ID': '9927584',
#   'ROAD_NO': 'M010',
#   'CWAY': 'S',
#   'COMMON_ROAD_NAME': 'Great Southern Hwy',
#   'LONGITUDE': '116.450932',
#   'LATITUDE': '-31.882154',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Hit Object',
#   'EVENT_TYPE': 'Involving Animal',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 1,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 7,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Morning'},
#  {'ACC_ID': '9909716',
#   'ROAD_NO': '1030953',
#   'CWAY': 'L',
#   'COMMON_ROAD_NAME': 'Beeliar Dr',
#   'LONGITUDE': '115.856837',
#   'LATITUDE': '-32.128231',
#   'ACCIDENT_TYPE': 'Midblock',
#   'EVENT_NATURE': 'Others',
#   'EVENT_TYPE': 'Others',
#   'TOTAL_BIKE_INVOLVED': 0,
#   'TOTAL_TRUCK_INVOLVED': 0,
#   'TOTAL_HEAVY_TRUCK_INVOLVED': 0,
#   'TOTAL_MOTOR_CYCLE_INVOLVED': 0,
#   'TOTAL_OTHER_VEHICLES_INVOLVED': 2,
#   'TOTAL_PEDESTRIANS_INVOLVED': 0,
#   'CRASH_TIME_HRS': 20,
#   'YEAR': 2018,
#   'MONTH': 11,
#   'CRASH_DAYWEEK': 'Sunday',
#   'CRASH_TIMEDAY': 'Evening'}]
