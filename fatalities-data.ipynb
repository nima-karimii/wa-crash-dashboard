# %%
import pandas as pd

# %%
csv_file = "Resources/ardd_fatal_crashes_aug2020.csv"
fatal_crashes_df = pd.read_csv(csv_file)
fatal_crashes_df
# Out:
#        Crash ID State  Month  Year   Dayweek   Time  Crash Type  \
# 0      20205010    WA      8  2020    Sunday  15:53      Single
# 1      20205030    WA      8  2020   Tuesday  17:00    Multiple
# 2      20201104   NSW      8  2020    Monday  16:30    Multiple
# 3      20201105   NSW      8  2020    Monday  09:20      Single
# 4      20201111   NSW      8  2020  Saturday  02:12      Single
# ...         ...   ...    ...   ...       ...    ...         ...
# 46450  19891498   NSW      1  1989    Sunday  14:35    Multiple
# 46451  19893020   Qld      1  1989    Sunday  04:00  Pedestrian
# 46452  19893344   Qld      1  1989    Sunday  01:00      Single
# 46453  19893229   Qld      1  1989    Sunday  17:00  Pedestrian
# 46454  19892467   Vic      1  1989    Sunday  01:15      Single
#
#        Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  \
# 0                      1                No                            No
# 1                      1                No                            No
# 2                      1                No                            No
# 3                      1                No                            No
# 4                      1                No                            No
# ...                  ...               ...                           ...
# 46450                  3                No                            -9
# 46451                  1                No                            -9
# 46452                  1                No                            -9
# 46453                  1                No                            -9
# 46454                  1                No                            No
#
#       Articulated Truck Involvement Speed Limit  National Remoteness Areas  \
# 0                                No          80                        NaN
# 1                                No          80                        NaN
# 2                                No          60   Inner Regional Australia
# 3                                No         100  Major Cities of Australia
# 4                                No          60  Major Cities of Australia
# ...                             ...         ...                        ...
# 46450                            No          80                        NaN
# 46451                            No          60                        NaN
# 46452                            No          60                        NaN
# 46453                            No          60                        NaN
# 46454                            No         100                        NaN
#
#                    SA4 Name 2016 National LGA Name 2017  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                       Riverina            Wagga Wagga
# 3                  Sydney - Ryde                Hornsby
# 4      Sydney - Inner South West          Georges River
# ...                          ...                    ...
# 46450                        NaN                    NaN
# 46451                        NaN                    NaN
# 46452                        NaN                    NaN
# 46453                        NaN                    NaN
# 46454                        NaN                    NaN
#
#               National Road Type Christmas Period Easter Period Day of week  \
# 0                            NaN               No            No     Weekend
# 1                            NaN               No            No     Weekday
# 2                     Local Road               No            No     Weekday
# 3      National or State Highway               No            No     Weekday
# 4                  Arterial Road               No            No     Weekend
# ...                          ...              ...           ...         ...
# 46450                        NaN              Yes            No     Weekend
# 46451                        NaN              Yes            No     Weekend
# 46452                        NaN              Yes            No     Weekend
# 46453                        NaN              Yes            No     Weekend
# 46454                        NaN              Yes            No     Weekend
#
#       Time of Day
# 0             Day
# 1             Day
# 2             Day
# 3             Day
# 4           Night
# ...           ...
# 46450         Day
# 46451       Night
# 46452       Night
# 46453         Day
# 46454       Night
#
# [46455 rows x 20 columns]

# %%
wa_five_years_fatal_crashes_df = fatal_crashes_df.loc[(fatal_crashes_df["Year"]>2014)&(fatal_crashes_df["Year"]<2020)&(fatal_crashes_df["State"]=="WA")]
wa_five_years_fatal_crashes_df
# Out:
#       Crash ID State  Month  Year    Dayweek   Time  Crash Type  \
# 685   20195026    WA     12  2019    Tuesday  02:40    Multiple
# 692   20195109    WA     12  2019  Wednesday  05:07  Pedestrian
# 693   20195055    WA     12  2019     Sunday  10:40    Multiple
# 694   20195098    WA     12  2019     Sunday  13:30      Single
# 715   20195115    WA     12  2019   Saturday  12:48      Single
# ...        ...   ...    ...   ...        ...    ...         ...
# 6208  20155066    WA      1  2015   Thursday  17:38    Multiple
# 6213  20155098    WA      1  2015    Tuesday  18:04    Multiple
# 6231  20155079    WA      1  2015     Monday  16:00      Single
# 6233  20155115    WA      1  2015     Sunday  22:20    Multiple
# 6240  20155082    WA      1  2015   Thursday  21:45      Single
#
#       Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  \
# 685                   1                No                            No
# 692                   1                No                            No
# 693                   1                No                            No
# 694                   1                No                            No
# 715                   1                No                            No
# ...                 ...               ...                           ...
# 6208                  1                No                            No
# 6213                  1                No                           Yes
# 6231                  1                No                            No
# 6233                  1                No                            No
# 6240                  1                No                            No
#
#      Articulated Truck Involvement Speed Limit  National Remoteness Areas  \
# 685                             No         110      Very Remote Australia
# 692                             No          90           Remote Australia
# 693                             No         100  Major Cities of Australia
# 694                             No          80      Very Remote Australia
# 715                             No         110      Very Remote Australia
# ...                            ...         ...                        ...
# 6208                           Yes         110   Outer Regional Australia
# 6213                            No         100  Major Cities of Australia
# 6231                            No          80   Outer Regional Australia
# 6233                            No          70  Major Cities of Australia
# 6240                            No         110   Inner Regional Australia
#
#                             SA4 Name 2016      National LGA Name 2017  \
# 685   Western Australia - Outback (North)               Ashburton (S)
# 692   Western Australia - Outback (North)                Karratha (C)
# 693                    Perth - South West                Cockburn (C)
# 694   Western Australia - Outback (South)              Coolgardie (S)
# 715   Western Australia - Outback (North)  Wyndham-East Kimberley (S)
# ...                                   ...                         ...
# 6208       Western Australia - Wheat Belt               Wandering (S)
# 6213                   Perth - South West                Melville (C)
# 6231       Western Australia - Wheat Belt                Brookton (S)
# 6233                   Perth - North West                Stirling (C)
# 6240                              Bunbury                  Harvey (S)
#
#              National Road Type Christmas Period Easter Period Day of week  \
# 685               Arterial Road               No            No     Weekday
# 692               Arterial Road              Yes            No     Weekday
# 693   National or State Highway               No            No     Weekend
# 694                  Local Road               No            No     Weekend
# 715   National or State Highway               No            No     Weekend
# ...                         ...              ...           ...         ...
# 6208  NATIONAL OR STATE HIGHWAY               No            No     Weekday
# 6213  NATIONAL OR STATE HIGHWAY               No            No     Weekday
# 6231                 LOCAL ROAD               No            No     Weekday
# 6233  NATIONAL OR STATE HIGHWAY               No            No     Weekend
# 6240  NATIONAL OR STATE HIGHWAY              Yes            No     Weekday
#
#      Time of Day
# 685        Night
# 692        Night
# 693          Day
# 694          Day
# 715          Day
# ...          ...
# 6208         Day
# 6213       Night
# 6231         Day
# 6233       Night
# 6240       Night
#
# [760 rows x 20 columns]

# %%
fatalities_data = wa_five_years_fatal_crashes_df
fatalities_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 685 to 6240
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       760 non-null    int64
#  1   State                          760 non-null    object
#  2   Month                          760 non-null    int64
#  3   Year                           760 non-null    int64
#  4   Dayweek                        760 non-null    object
#  5   Time                           760 non-null    object
#  6   Crash Type                     760 non-null    object
#  7   Number Fatalities              760 non-null    int64
#  8   Bus
# Involvement               760 non-null    object
#  9   Heavy Rigid Truck Involvement  760 non-null    object
#  10  Articulated Truck Involvement  760 non-null    object
#  11  Speed Limit                    760 non-null    object
#  12  National Remoteness Areas      685 non-null    object
#  13  SA4 Name 2016                  695 non-null    object
#  14  National LGA Name 2017         691 non-null    object
#  15  National Road Type             684 non-null    object
#  16  Christmas Period               760 non-null    object
#  17  Easter Period                  760 non-null    object
#  18  Day of week                    760 non-null    object
#  19  Time of Day                    760 non-null    object
# dtypes: int64(4), object(16)
# memory usage: 124.7+ KB

# %%
fatalities_data.to_csv("fatalities_data.csv")
